# %%
from dask.distributed import Client, LocalCluster

# %%
cluster = LocalCluster(memory_limit=0, scheduler_port=9001)
# Out:
# 2022-10-20 20:36:11,584 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-a2ivzjj3', purging

# %%
cluster.adapt(minimum=1, maximum=6)

# %%
cluster
# Out:
# LocalCluster(66933448, 'tcp://127.0.0.1:9001', workers=6, threads=18)
